-- %%
DROP TABLE IF EXISTS fuel_price_dev.gold.agg_classement_stations_moins_cheres;
DROP TABLE IF EXISTS fuel_price_dev.gold.agg_evolution_prix_national;
DROP TABLE IF EXISTS fuel_price_dev.gold.agg_taux_rupture_par_region;
DROP TABLE IF EXISTS fuel_price_dev.gold.agg_prix_moyen_par_departement_jour;
